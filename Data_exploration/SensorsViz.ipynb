# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ee

# %%
from osgeo import gdal
import sys
import os

# %%
pip install chart-studio
# Out:
# ...
#      |████████████████████████████████| 71kB 2.5MB/s
# ...

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
# Above is a special style template for matplotlib, highly useful for visualizing time series data
# %matplotlib inline
from pylab import rcParams
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
import math
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/sensors_dataset.csv", index_col='date_time', parse_dates=['date_time'])  # Reading the dataset for vizualisation

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(df['soil_moisture_depth_0.050'], label='0.05')
#plt.plot(df['soil_moisture_depth_0.5'], label='0.5')
#plt.plot(df['soil_moisture_depth_0.1'], label='0.1')
#plt.plot(df['soil_moisture_depth_0.2'], label='0.2')


plt.legend(frameon=False)

# %%
df['soil_moisture_depth_0.050'].asfreq('M').plot()
plt.show()

# %%
df['2019':'2020'].plot(subplots=True, figsize=(10,12))
plt.show()

# %%
df['Change'] = df['soil_moisture_depth_0.050'].div(df['soil_moisture_depth_0.050'].shift())
df['Change'].plot(figsize=(20,8))

# %%
df['soil_moisture_depth_0.050'].diff().plot(figsize=(20,6))

# %%
df['soil_moisture_depth_0.050'].plot()
df['soil_moisture_depth_0.5'].plot()
plt.legend(['0.05D','0.5D'])
plt.show()

# %%
trace = go.Ohlc(x=df['06-2019'].index,
                open=df[]['06-2019'],
                high=df['06-2019'],
                low=df['06-2019'],
                close=df['06-2019'])
data = [trace]
iplot(data, filename='simple_ohlc')
