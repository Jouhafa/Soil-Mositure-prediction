# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Zakarya/datasets/Cropped_dataset.csv')

# %%
df.head()
# Out:
#     date_time  ...                                         Image_data
# 0  2019-04-01  ...  /content/drive/MyDrive/dump_test20190401T16390...
# 1  2019-05-26  ...  /content/drive/MyDrive/dump_test20190526T16384...
# 2  2019-05-31  ...  /content/drive/MyDrive/dump_test20190531T16390...
# 3  2019-06-05  ...  /content/drive/MyDrive/dump_test20190605T16384...
# 4  2019-05-01  ...  /content/drive/MyDrive/dump_test20190501T16390...
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#        soil_moisture_depth_0.1  ...  soil_moisture_depth_0.050
# count                68.000000  ...                  68.000000
# mean                  0.321721  ...                   0.320397
# std                   0.087506  ...                   0.105542
# min                   0.185000  ...                   0.170000
# 25%                   0.239000  ...                   0.220750
# 50%                   0.334500  ...                   0.339000
# 75%                   0.395750  ...                   0.417500
# max                   0.503000  ...                   0.523000
#
# [8 rows x 4 columns]

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(df['soil_moisture_depth_0.050'], label='0.05')
plt.plot(df['soil_moisture_depth_0.5'], label='0.5')
plt.plot(df['soil_moisture_depth_0.1'], label='0.1')
plt.plot(df['soil_moisture_depth_0.2'], label='0.2')


plt.legend(frameon=False)
